# %% [markdown]
# # My Jupyter Notebook in GitHub

# %% [markdown]
# __Danielle Robinson__
#
#
# Data Scientist

# %% [markdown]
# _I am interested in becoming a Data Scientist because of my love of coding and technology and curiosity of the world around us in the form of data_

# %% [markdown]
# ### Below, I will be finding the sum of an equation using Python

# %%
(15 + 35)
# Out:
# 50

# %% [markdown]
# In This notebook I:
# 1. Stated my name
# 2. Wrote a sentence
# 3. Entered an equation
#
#
# __[Cheers to Learning!](https://giphy.com/gifs/sesamestreet-sesame-street-50th-anniversary-kyLYXonQYYfwYDIeZl)__
# ![DB4D2F0C-6EB3-4AA6-A2E8-6EAEBBE7F899.jpeg](attachment:DB4D2F0C-6EB3-4AA6-A2E8-6EAEBBE7F899.jpeg)
